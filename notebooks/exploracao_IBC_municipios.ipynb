# %%
#bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#carregamento inicial dos dados
df = pd.read_csv("../data/raw/IBC_municipios_indicadores_normalizados.csv", encoding='latin-1', sep=';')

# %%
#visualização inicial
df.head()
# Out:
#    ï»¿Ano  CÃ³digo MunicÃ­pio                  MunicÃ­pio  UF    IBC  \
# 0    2024             1100015  Alta Floresta D'Oeste - RO  RO  29,45
# 1    2024             1100023              Ariquemes - RO  RO  55,80
# 2    2024             1100031                 Cabixi - RO  RO  26,58
# 3    2024             1100049                 Cacoal - RO  RO  59,87
# 4    2024             1100056             Cerejeiras - RO  RO  45,08
#
#   Cobertura Pop. 4G5G Densidade SMP  HHI SMP Densidade SCM  HHI SCM  \
# 0             64,9073         48,18       44         10,26       73
# 1             86,0454         60,08       51         39,64       78
# 2             48,2041         44,78       35         38,97       10
# 3             82,1237         63,77       56         60,32       78
# 4             88,5058         68,41       49         25,83       48
#
#   Adensamento EstaÃ§Ãµes  Fibra Cobertura Ã¡rea agricultÃ¡vel
# 0                  13,13      0                        8,9309
# ...

# %%
# info gerais 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22280 entries, 0 to 22279
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ï»¿Ano                         22280 non-null  int64
#  1   CÃ³digo MunicÃ­pio             22280 non-null  int64
#  2   MunicÃ­pio                     22280 non-null  object
#  3   UF                             22280 non-null  object
#  4   IBC                            22280 non-null  object
#  5   Cobertura Pop. 4G5G            22280 non-null  object
#  6   Densidade SMP                  22280 non-null  object
#  7   HHI SMP                        22280 non-null  int64
#  8   Densidade SCM                  22280 non-null  object
#  9   HHI SCM                        22280 non-null  int64
#  10  Adensamento EstaÃ§Ãµes         22280 non-null  object
#  11  Fibra                          22280 non-null  int64
# ...

# %%
#valores ausentes
df.isnull().sum()
# Out:
# ï»¿Ano                               0
# CÃ³digo MunicÃ­pio                   0
# MunicÃ­pio                           0
# UF                                   0
# IBC                                  0
# Cobertura Pop. 4G5G                  0
# Densidade SMP                        0
# HHI SMP                              0
# Densidade SCM                        0
# HHI SCM                              0
# Adensamento EstaÃ§Ãµes               0
# Fibra                                0
# Cobertura Ã¡rea agricultÃ¡vel    16710
# dtype: int64

# %%
#features/colunas
df.columns
# Out:
# Index(['ï»¿Ano', 'CÃ³digo MunicÃ­pio', 'MunicÃ­pio', 'UF', 'IBC',
#        'Cobertura Pop. 4G5G', 'Densidade SMP', 'HHI SMP', 'Densidade SCM',
#        'HHI SCM', 'Adensamento EstaÃ§Ãµes', 'Fibra',
#        'Cobertura Ã¡rea agricultÃ¡vel'],
#       dtype='object')

# %%
df.describe(include='all')
# Out:
#               ï»¿Ano  CÃ³digo MunicÃ­pio                  MunicÃ­pio     UF  \
# count   22280.000000        2.228000e+04                       22280  22280
# unique           NaN                 NaN                        5570     27
# top              NaN                 NaN  Alta Floresta D'Oeste - RO     MG
# freq             NaN                 NaN                           4   3412
# mean     2022.500000        3.253591e+06                         NaN    NaN
# std         1.118059        9.848440e+05                         NaN    NaN
# min      2021.000000        1.100015e+06                         NaN    NaN
# 25%      2021.750000        2.512101e+06                         NaN    NaN
# 50%      2022.500000        3.146280e+06                         NaN    NaN
# 75%      2023.250000        4.119202e+06                         NaN    NaN
# max      2024.000000        5.300108e+06                         NaN    NaN
#
# ...
